# %% [markdown]
# An Analysis of Preference of Manual vs Automatic Transmission Cars in County Cork

# %% [markdown]
# Introduction:
# As an American living in Rosscarbery,County Cork, I am curious as to the breakdown of preferences for manual vs automatic transmission cars. Personally, I prefer driving automatic cars, so I'm wondering how much of an outsider I am in that respect.
#
# So, using the actual population of Rosscarbery, 1000 people, I will create my dataset using the following variables:
#
# Age,
# Transmission (manual/automatic),
# Sex (Male/Female),
# Make of car

# %%
#import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Use numpy to generate a random array of ages 
import numpy as np
rng = np.random.default_rng()
ages = rng.integers(18, 76, 1000)
print(ages)
# Out:
# [60 33 19 42 31 25 21 63 72 49 35 66 75 32 57 69 71 61 72 19 22 61 31 74
#  54 27 71 22 33 32 32 29 62 32 54 56 38 51 53 62 54 36 47 59 23 52 57 63
#  54 63 73 57 38 22 46 66 42 60 35 28 36 38 53 29 52 58 61 58 42 60 37 75
#  67 47 64 56 20 30 65 19 30 39 23 59 18 55 57 22 21 30 63 53 75 58 53 59
#  19 49 47 66 57 34 38 34 40 59 73 52 75 51 46 53 70 63 18 58 38 65 34 73
#  42 21 30 69 51 42 59 25 47 49 28 54 50 30 60 49 47 24 71 52 38 44 44 57
#  38 46 43 75 67 61 43 51 54 30 74 28 50 32 70 68 55 21 35 29 24 74 24 48
#  59 22 52 35 29 59 69 39 18 27 69 48 74 65 63 38 71 42 27 53 18 51 65 61
#  43 60 45 54 64 46 36 34 55 38 72 30 71 21 70 62 28 30 51 54 68 21 62 67
#  32 37 40 66 49 43 22 50 50 60 35 29 41 53 24 75 27 60 19 40 56 32 70 34
#  44 37 59 70 73 42 67 27 56 44 35 19 40 39 72 33 67 33 40 74 57 75 53 45
#  53 53 71 73 30 50 41 32 53 40 53 46 21 26 64 52 30 70 52 38 71 31 18 48
#  62 74 61 67 50 50 30 45 50 65 26 64 39 21 65 25 23 44 69 37 31 55 74 56
# ...

# %%
import numpy as np
#Use numpy to generate a random array of male/female sexes
sexes = np.random.choice(['male', 'female'], 1000, p=[0.60, 0.40])
print(sexes)
# Out:
# ['female' 'female' 'female' 'male' 'male' 'male' 'male' 'male' 'male'
#  'male' 'male' 'male' 'female' 'male' 'male' 'female' 'male' 'female'
#  'male' 'male' 'male' 'male' 'male' 'female' 'male' 'male' 'female' 'male'
#  'male' 'female' 'male' 'female' 'female' 'male' 'female' 'male' 'male'
#  'female' 'male' 'male' 'female' 'male' 'female' 'female' 'female'
#  'female' 'male' 'male' 'male' 'female' 'male' 'male' 'female' 'female'
#  'female' 'female' 'female' 'female' 'female' 'male' 'female' 'female'
#  'male' 'male' 'male' 'male' 'female' 'male' 'female' 'male' 'male' 'male'
#  'female' 'female' 'male' 'male' 'male' 'female' 'female' 'male' 'male'
#  'male' 'male' 'male' 'female' 'male' 'female' 'male' 'female' 'male'
#  'female' 'male' 'male' 'male' 'male' 'female' 'male' 'female' 'male'
#  'female' 'male' 'male' 'male' 'male' 'female' 'female' 'female' 'female'
#  'male' 'male' 'female' 'female' 'male' 'female' 'male' 'male' 'male'
# ...

# %%
import numpy as np
#Use numpy to generate a random array of transmissions manual/automatic
transmission = np.random.choice(['manual', 'automatic'], 1000, p=[0.70, 0.30])
print(transmission)
# Out:
# ['automatic' 'manual' 'manual' 'manual' 'manual' 'automatic' 'manual'
#  'manual' 'automatic' 'automatic' 'automatic' 'automatic' 'automatic'
#  'manual' 'automatic' 'manual' 'automatic' 'manual' 'automatic' 'manual'
#  'manual' 'automatic' 'manual' 'manual' 'automatic' 'automatic' 'manual'
#  'manual' 'manual' 'automatic' 'manual' 'manual' 'manual' 'manual'
#  'manual' 'manual' 'manual' 'manual' 'manual' 'manual' 'manual'
#  'automatic' 'automatic' 'manual' 'automatic' 'automatic' 'manual'
#  'manual' 'manual' 'manual' 'manual' 'manual' 'manual' 'manual' 'manual'
#  'automatic' 'manual' 'manual' 'manual' 'automatic' 'manual' 'manual'
#  'manual' 'automatic' 'manual' 'manual' 'manual' 'manual' 'manual'
#  'manual' 'manual' 'manual' 'manual' 'automatic' 'manual' 'manual'
#  'manual' 'automatic' 'manual' 'manual' 'manual' 'manual' 'manual'
#  'automatic' 'manual' 'manual' 'automatic' 'manual' 'manual' 'manual'
#  'automatic' 'manual' 'manual' 'manual' 'manual' 'manual' 'manual'
# ...

# %%
import numpy as np
#Use numpy to generate a random array of car makes Skoda/VW/Toyota/Peugot
carmake = np.random.choice(['skoda', 'vw', 'toyota', 'peugeot'], 1000, p=[0.30, 0.25, 0.35, 0.10])
print(carmake)
# Out:
# ['toyota' 'peugeot' 'vw' 'skoda' 'skoda' 'skoda' 'toyota' 'toyota' 'skoda'
#  'skoda' 'skoda' 'skoda' 'skoda' 'skoda' 'toyota' 'toyota' 'toyota' 'vw'
#  'peugeot' 'vw' 'toyota' 'toyota' 'skoda' 'skoda' 'skoda' 'vw' 'toyota'
#  'toyota' 'vw' 'toyota' 'vw' 'toyota' 'vw' 'toyota' 'vw' 'toyota' 'toyota'
#  'vw' 'skoda' 'vw' 'peugeot' 'toyota' 'toyota' 'toyota' 'toyota' 'skoda'
#  'toyota' 'toyota' 'peugeot' 'vw' 'toyota' 'vw' 'vw' 'vw' 'peugeot'
#  'skoda' 'peugeot' 'vw' 'toyota' 'skoda' 'toyota' 'vw' 'vw' 'vw' 'skoda'
#  'skoda' 'toyota' 'skoda' 'toyota' 'vw' 'skoda' 'toyota' 'peugeot' 'skoda'
#  'toyota' 'skoda' 'vw' 'vw' 'vw' 'vw' 'vw' 'toyota' 'skoda' 'toyota'
#  'peugeot' 'vw' 'vw' 'vw' 'toyota' 'skoda' 'toyota' 'skoda' 'toyota'
#  'toyota' 'skoda' 'skoda' 'skoda' 'toyota' 'toyota' 'toyota' 'toyota'
#  'toyota' 'skoda' 'vw' 'skoda' 'vw' 'peugeot' 'vw' 'vw' 'skoda' 'skoda'
#  'vw' 'toyota' 'toyota' 'skoda' 'toyota' 'vw' 'skoda' 'skoda' 'toyota'
# ...

# %%
import numpy as np
rng = np.random.default_rng()
ages = rng.integers(18, 76, 1000)
# print(ages)

#Use numpy to generate a random array of male/female sexes
sexes = np.random.choice(['male', 'female'], 1000, p=[0.60, 0.40])
# print(sexes)

#Use numpy to generate a random array of car makes Skoda/VW/Toyota/Peugot
carmake = np.random.choice(['skoda', 'vw', 'toyota', 'peugeot'], 1000, p=[0.30, 0.25, 0.35, 0.10])
# print(carmake)

#Use numpy to generate a random array of transmissions manual/automatic
transmission = np.random.choice(['manual', 'automatic'], 1000, p=[0.70, 0.30])
# print(transmission)

import pandas as pd
d = {'Age': ages , 'Sex': sexes , 'Car Make': carmake ,'Transmission': transmission}
df = pd.DataFrame(data=d)
df
# Out:
#      Age     Sex Car Make Transmission
# 0     55  female    skoda       manual
# 1     38    male    skoda       manual
# 2     55  female       vw       manual
# 3     48    male   toyota       manual
# 4     34  female       vw       manual
# ..   ...     ...      ...          ...
# 995   42    male   toyota       manual
# 996   19    male    skoda       manual
# 997   63  female   toyota       manual
# 998   68    male       vw    automatic
# 999   43  female    skoda       manual
#
# [1000 rows x 4 columns]
